# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/Ames_Housing_Data.csv', sep=',')
df1
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
df2 = pd.read_csv('data/bank-full.csv', sep=',')
df2
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df3 = pd.read_csv('data/census_income_data.csv', sep=',')
df3
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df1.value_counts()
# Out:
# Series([], dtype: int64)

# %%
df1['Lot Shape'].value_counts()
# Out:
# Reg    1859
# IR1     979
# IR2      76
# IR3      16
# Name: Lot Shape, dtype: int64

# %%
df1['Misc Feature'].value_counts()
# Out:
# Shed    95
# Gar2     5
# Othr     4
# Elev     1
# TenC     1
# Name: Misc Feature, dtype: int64

# %%
df1['Misc Feature']=df1['Misc Feature'].fillna('none')

# %%
df1['Misc Feature'].value_counts()
# Out:
# none    2824
# Shed      95
# Gar2       5
# Othr       4
# Elev       1
# TenC       1
# Name: Misc Feature, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df1.sample(250))
# Out:
# <AxesSubplot:>

# %%
df1['SalePrice'].or
# Out:
# 0       215000
# 1       105000
# 2       172000
# 3       244000
# 4       189900
#          ...
# 2925    142500
# 2926    131000
# 2927    132000
# 2928    170000
# 2929    188000
# Name: SalePrice, Length: 2930, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df4 = df1.loc[:,['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area']]

corr_df1 = df4.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_df1, annot=True)
plt.show()

# %%
df4.drop['MS Zoning']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4048/1596675552.py in <module>
# ----> 1 df4.drop['MS Zoning']
#
# TypeError: 'method' object is not subscriptable

# %%
df4 = df4.drop('MS Zoning', axis=1)

# %%
df4
# Out:
#       MS SubClass  Lot Frontage  Lot Area
# 0              20         141.0     31770
# 1              20          80.0     11622
# 2              20          81.0     14267
# 3              20          93.0     11160
# 4              60          74.0     13830
# ...           ...           ...       ...
# 2925           80          37.0      7937
# 2926           20           NaN      8885
# 2927           85          62.0     10441
# 2928           20          77.0     10010
# 2929           60          74.0      9627
#
# [2930 rows x 3 columns]

# %%
df4.describe()
# Out:
#        MS SubClass  Lot Frontage       Lot Area
# count  2930.000000   2440.000000    2930.000000
# mean     57.387372     69.224590   10147.921843
# std      42.638025     23.365335    7880.017759
# min      20.000000     21.000000    1300.000000
# 25%      20.000000     58.000000    7440.250000
# 50%      50.000000     68.000000    9436.500000
# 75%      70.000000     80.000000   11555.250000
# max     190.000000    313.000000  215245.000000

# %%
y = list(df1.SalePrice)

# %%
y
# Out:
# [215000,
#  105000,
#  172000,
#  244000,
#  189900,
#  195500,
#  213500,
#  191500,
#  236500,
#  189000,
#  175900,
#  185000,
#  180400,
#  171500,
#  212000,
#  538000,
#  164000,
#  394432,
#  141000,
#  210000,
#  190000,
#  170000,
#  216000,
#  149000,
#  149900,
#  142000,
#  126000,
#  115000,
#  184000,
#  96000,
#  105500,
#  88000,
#  127500,
#  149900,
#  120000,
#  146000,
#  376162,
#  306000,
#  395192,
#  290941,
#  220000,
#  275000,
#  259000,
#  214000,
#  611657,
#  224000,
#  500000,
#  320000,
#  319900,
#  205000,
#  175500,
#  199500,
#  160000,
#  192000,
#  184500,
#  216500,
#  185088,
#  180000,
#  222500,
#  333168,
#  355000,
#  260400,
#  325000,
#  290000,
#  221000,
#  410000,
#  221500,
#  204500,
#  215200,
#  262500,
#  254900,
#  271500,
#  233000,
#  181000,
#  205000,
#  143000,
#  189000,
#  99500,
#  125000,
#  194500,
#  152000,
#  171000,
#  67500,
#  112000,
#  148000,
#  138500,
#  122000,
#  133000,
#  127000,
#  169000,
#  190000,
# ...

# %%
import sklearn
import pandas 
import numpy
import matplotlib
from sklearn import datasets
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df4, y, test_size=0.30, random_state=42)

# %%
tree = DecisionTreeClassifier(max_depth=2, random_state = 42)
tree.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4048/1630654739.py in <module>
#       1 tree = DecisionTreeClassifier(max_depth=2, random_state = 42)
# ----> 2 tree.fit(X_train,y_train)
#
# ~\miniconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\miniconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     156             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 157             X, y = self._validate_data(X, y,
# ...
